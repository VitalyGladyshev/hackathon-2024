# %% [markdown]
# # Подготовка сервера

# %%
# !pip list

# %%
import numpy as np
import pandas as pd

import pickle

import os
import getpass

# %% [markdown]
# ## Подготовка модели GigaChat MAX

# %%
def set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

# %%
set_env("GIGACHAT_API_KEY")

# %%
# !pip install langchain-gigachat
# Out:
# Requirement already satisfied: langchain-gigachat in c:\users\glvv2\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: gigachat<0.2.0,>=0.1.36 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-gigachat) (0.1.36)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-gigachat) (0.3.25)
# Requirement already satisfied: types-requests<3.0,>=2.32 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-gigachat) (2.32.0.20241016)
# Requirement already satisfied: httpx<1 in c:\users\glvv2\anaconda3\lib\site-packages (from gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.27.0)
# Requirement already satisfied: pydantic>=1 in c:\users\glvv2\anaconda3\lib\site-packages (from gigachat<0.2.0,>=0.1.36->langchain-gigachat) (2.8.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (4.11.0)
# Requirement already satisfied: urllib3>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from types-requests<3.0,>=2.32->langchain-gigachat) (2.2.3)
# Requirement already satisfied: anyio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (4.2.0)
# Requirement already satisfied: certifi in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (1.0.2)
# Requirement already satisfied: idna in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (3.7)
# Requirement already satisfied: sniffio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\glvv2\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\glvv2\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-gigachat) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain-gigachat) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain-gigachat) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain-gigachat) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain-gigachat) (3.3.2)

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_gigachat.chat_models import GigaChat

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\glvv2\anaconda3\lib\site-packages (0.3.12)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (0.2.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\glvv2\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\glvv2\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain) (2.1)

# %%
from langchain.schema import HumanMessage

# %%
llm_max = GigaChat(
    credentials=os.environ.get("GIGACHAT_API_KEY"),
    scope="GIGACHAT_API_PERS",
    model="GigaChat-Max",
    # Отключает проверку наличия сертификатов НУЦ Минцифры
    verify_ssl_certs=False,
    streaming=True, #False,
)

# %%
question = "Рассскажи подробно о достопримечательностях Пекина"
answer = llm_max([HumanMessage(content=question)])

# %%
print('Пекин – столица Китая и один из самых древних городов мира с богатой историей и культурой. Здесь сосредоточено множество достопримечательностей, которые привлекают туристов со всего света. Вот некоторые из них:\n\n### 1. **Великая Китайская стена (长城)**\n   Это одно из самых известных сооружений в мире, которое простирается более чем на 21 тысячу километров. Великая стена была построена для защиты китайских территорий от набегов кочевников. В окрестностях Пекина находятся несколько участков стены, наиболее популярные среди которых Бадалин (八达岭), Мутяньюй (慕田峪) и Симатай (司马台). Эти участки хорошо отреставрированы и оборудованы для посещения туристами.\n\n### 2. **Запретный город (紫禁城)**\n   Запретный город, также известный как Дворец Гугун, был резиденцией императоров династии Мин и Цин. Он расположен в самом центре Пекина и является крупнейшим дворцовым комплексом в мире. Внутри комплекса находится около 980 зданий, украшенных традиционными китайскими орнаментами и росписями. Запретный город включен в список Всемирного наследия ЮНЕСКО.\n\n### 3. **Храм Неба (天坛)**\n   Храм Неба – это религиозное сооружение, построенное в XV веке во времена династии Мин. Он использовался императорами для проведения ритуалов поклонения небу и молений о хорошем урожае. Комплекс состоит из нескольких храмов и павильонов, окруженных парком. Самым известным зданием храма является Круглый алтарь (圜丘坛).\n\n### 4. **Площадь Тяньаньмэнь (天安门广场)**\n   Площадь Тяньаньмэнь – самая большая городская площадь в мире, расположенная перед входом в Запретный город.
MB 5.1 MB/s eta 0:00:03
#    -------------------------------------- - 193.5/203.0 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 194.8/203.0 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 196.3/203.0 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 197.9/203.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  199.5/203.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  201.1/203.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  202.9/203.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 203.0/203.0 MB 5.2 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------- ----------------------------- 1.6/6.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.2 MB 9.1 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 8.6 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --------------------------------- ------ 1.3/1.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.4 MB/s eta 0:00:00
# Downloading torchaudio-2.5.1-cp312-cp312-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------------------- -------------- 1.6/2.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: sympy, torch, torchvision, torchaudio
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.13.1 torch-2.5.1 torchaudio-2.5.1 torchvision-0.20.1

# %%
import torch
import torch.nn.functional as F

# %%
# !pip install cudatoolkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement cudatoolkit (from versions: none)
# ERROR: No matching distribution found for cudatoolkit

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\glvv2\anaconda3\lib\site-packages (4.47.0)
# Requirement already satisfied: filelock in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\glvv2\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)
# Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# Successfully installed tokenizers-0.21.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\glvv2\anaconda3\Lib\site-packages\~-kenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.

# %%
from transformers import AutoTokenizer, AutoModel

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\glvv2\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (4.47.0)
# Requirement already satisfied: tqdm in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (0.27.0)
# Requirement already satisfied: Pillow in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: networkx in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\glvv2\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\glvv2\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\glvv2\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer

# %%
tokenizer_mul_e5_large = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-large')
model_mul_e5_large = AutoModel.from_pretrained('intfloat/multilingual-e5-large')

# %%
def get_embedding(sentence):

    #Mean Pooling - Take attention mask into account for correct averaging
    def _mean_pooling(model_output, attention_mask):
        token_embeddings = model_output[0] #First element of model_output contains all token embeddings
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

    # Tokenize sentences
    encoded_input = tokenizer_mul_e5_large([sentence], padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model_mul_e5_large(**encoded_input)

    # Perform pooling
    sentence_embeddings = _mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    return sentence_embeddings

# %%
emb_database_test = torch.empty((0, 1024), dtype=torch.float32)

# %%
locations = ["Лондон", "Париж", "Пекин", "Москва"]

# %%
for location in locations:
    emb = get_embedding(location)
    emb_database_test = torch.cat((emb_database_test, emb), 0)

# %%
def get_cos_sim_test(question):
    emb = get_embedding(question)
    cos_sim = F.cosine_similarity(emb_database_test, emb, dim=1, eps=1e-8)
    return cos_sim

# %%
cos_sim = get_cos_sim_test("Достопримечательности Китая")
cos_sim
# Out:
# tensor([0.7401, 0.7357, 0.7943, 0.7326])

# %%
cos_sim = get_cos_sim_test("Достопримечательности Англии")
cos_sim
# Out:
# tensor([0.7891, 0.7370, 0.7224, 0.7283])

# %%
cos_sim = get_cos_sim_test("Достопримечательности Франции")
cos_sim
# Out:
# tensor([0.7427, 0.7919, 0.7160, 0.7389])

# %%
cos_sim = get_cos_sim_test("Достопримечательности России")
cos_sim
# Out:
# tensor([0.7289, 0.7253, 0.7188, 0.7739])

# %%
def get_max_cos_sim(cos_sim) -> tuple[int]:
    max_el = 0
    ind_max_el = 0
    for i, el in enumerate(cos_sim):
        if el.item() > max_el:
            max_el = el.item()
            ind_max_el = i

    return (max_el, ind_max_el)

# %%
get_max_cos_sim(cos_sim)
# Out:
# (0.7739477157592773, 3)

# %% [markdown]
# ### Загрузка датасета

# %%
data = pd.read_csv("2024_12_14 China full 02.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Chapters     156 non-null    object
#  1   Subchapters  156 non-null    object
#  2   RAW          156 non-null    object
#  3   Clean_Text   156 non-null    object
#  4   Requests     156 non-null    object
#  5   HTML         156 non-null    object
#  6   File_name    156 non-null    object
# dtypes: object(7)
# memory usage: 8.7+ KB

# %%
data.head()
# Out:
#            Chapters           Subchapters  \
# 0             КИТАЙ              ВВЕДЕНИЕ
# 1  ОРГАНИЗАЦИЯ ТУРА  КАК ОРГАНИЗОВАТЬ ТУР
# 2              ВИЗЫ                  ВИЗЫ
# 3         СТРАХОВКА             СТРАХОВКА
# 4         ГОСТИНИЦЫ       ВЫБОР ГОСТИНИЦЫ
#
#                                                  RAW  \
# 0  Трудно себе представить более загадочную, свое...
# 1  Если Вы готовы к самостоятельному путешествию,...
# 2  Китай Согласно «Закону КНР о контроле над въез...
# 3  Для поездки в Китай необходимо приобрести меди...
# 4  Выбрать место проживания в Китае очень просто,...
#
#                                           Clean_Text  \
# 0  Трудно себе представить более загадочную, свое...
# 1  Если вы готовы к самостоятельному путешествию,...
# 2  Китай Согласно «Закону КНР о контроле над въез...
# 3  Для поездки в Китай необходимо приобрести меди...
# 4  Выбрать место проживания в Китае очень просто,...
#
#                                             Requests  \
# 0  Какова площадь Китая по сравнению с другими ст...
# 1  Как забронировать гостиницу и авиабилеты через...
# 2  Как получить визу в Китай?  \nКакие документы ...
# 3  - Как оформить медицинскую страховку для поезд...
# 4  Какой единственный вид размещения доступен тур...
#
#                                                 HTML  \
# 0  ```html\n<!DOCTYPE html>\n<html lang="ru">\n<h...
# 1  ```html\n<!DOCTYPE html>\n<html lang="ru">\n<h...
# 2  ```html\n<!DOCTYPE html>\n<html lang="ru">\n<h...
# 3  ```html\n<!DOCTYPE html>\n<html lang="ru">\n<h...
# 4  ```html\n<!DOCTYPE html>\n<html lang="ru">\n<h...
#
#                                         File_name
# 0                         001_китай_введение.html
# 1  002_организация_тура_как_организовать_тур.html
# 2                              003_визы_визы.html
# 3                    004_страховка_страховка.html
# 4              005_гостиницы_выбор_гостиницы.html

# %% [markdown]
# ### Формирование базы эмбеддингов

# %%
limits = []

# %%
emb_database = torch.empty((0, 1024), dtype=torch.float32)

# %%
for ind in range(data.shape[0]):
    print(f"{ind+1} {data['Chapters'][ind]}")
    requests = data['Requests'][ind].split("\n")
    limits.append(len)
    for question in requests:
        req = f"{data['Chapters'][ind]} {data['Subchapters'][ind]} {question.strip()}"

        # print(req)
        emb = get_embedding(req)
        emb_database = torch.cat((emb_database, emb), 0)
    break
# Out:
# 1 КИТАЙ

# %% [markdown]
# ## Вектоная база Chroma

# %%
# pip install -qU "langchain-chroma>=0.1.2"
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\glvv2\anaconda3\Lib\site-packages\~crypt'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\glvv2\anaconda3\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.47.0 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.

# %%
from chromadb.utils import embedding_functions

# %%
from sentence_transformers import SentenceTransformer

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.12-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.12 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (0.3.12)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (0.2.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.12->langchain-community) (0.3.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.12->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\glvv2\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\glvv2\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\glvv2\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Downloading langchain_community-0.3.12-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.5 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 4.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, marshmallow, httpx-sse, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.12 marshmallow-3.23.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade --quiet  langchain sentence_transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in c:\users\glvv2\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain_huggingface) (0.27.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain_huggingface) (0.3.25)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain_huggingface) (3.3.1)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain_huggingface) (0.21.0)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain_huggingface) (4.47.0)
# Requirement already satisfied: filelock in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\glvv2\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (8.2.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.1)
# Requirement already satisfied: scipy in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: Pillow in c:\users\glvv2\anaconda3\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (10.4.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\glvv2\anaconda3\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\glvv2\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\glvv2\anaconda3\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\glvv2\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\glvv2\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.8.30)
# Requirement already satisfied: networkx in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.3)
# Requirement already satisfied: jinja2 in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\glvv2\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: colorama in c:\users\glvv2\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain_huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\glvv2\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\glvv2\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: anyio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\glvv2\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\glvv2\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\glvv2\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

# %%
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="intfloat/multilingual-e5-large")
# sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
# from langchain_community.embeddings import HuggingFaceBgeEmbeddings

# model_name = "sentence-transformers/all-MiniLM-L6-v2"
# model_kwargs = {"device": "cpu"}
# # encode_kwargs = {"normalize_embeddings": True}
# sentence_transformer_ef = HuggingFaceBgeEmbeddings(
#     model_name=model_name, model_kwargs=model_kwargs, # encode_kwargs=encode_kwargs
# )

# sentence_transformer_ef_cl = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
sentence_transformer_ef_cl = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")

# %%
import chromadb

# %%
persistent_client = chromadb.PersistentClient(path="./example_db_0")

# %%
collection = persistent_client.get_or_create_collection("example_collection", embedding_function=sentence_transformer_ef)

# %%
from uuid import uuid4

# %%
documents = [
    "Какие достопримечательности в Шанхае?",
    "Какие местные блюда в Шанхае?",
    "Какие достопримечательности в Пекине?",
    "Какие местные блюда в Пекине?",
    "Какие достопримечательности в Ухане?",
    "Какие местные блюда в Ухане?",
    "Какие достопримечательности в Гонконге?",
    "Какие местные блюда в Гонконге?",
    "Какие достопримечательности в Макао?",
    "Какие местные блюда в Макао?"
]

metadata = [
    {"Chapters": "ШАНХАЙ", "Subchapters": "ДОСТОПРИМЕЧАТЕЛЬНОСТИ"},
    {"Chapters": "ШАНХАЙ", "Subchapters": "КУХНЯ"},
    {"Chapters": "ПЕКИН", "Subchapters": "ДОСТОПРИМЕЧАТЕЛЬНОСТИ"},
    {"Chapters": "ПЕКИН", "Subchapters": "КУХНЯ"},
    {"Chapters": "УХАНЬ", "Subchapters": "ДОСТОПРИМЕЧАТЕЛЬНОСТИ"},
    {"Chapters": "УХАНЬ", "Subchapters": "КУХНЯ"},
    {"Chapters": "ГОНКОНГ", "Subchapters": "ДОСТОПРИМЕЧАТЕЛЬНОСТИ"},
    {"Chapters": "ГОНКОНГ", "Subchapters": "КУХНЯ"},
    {"Chapters": "МАКАО", "Subchapters": "ДОСТОПРИМЕЧАТЕЛЬНОСТИ"},
    {"Chapters": "МАКАО", "Subchapters": "КУХНЯ"}
]

uuids = [str(uuid4()) for _ in range(len(documents))]

# %%
collection.add(
    ids=uuids, 
    documents=documents,
    metadatas=metadata
)

# %%
collection.get()
# Out:
# {'ids': ['88bcb09d-e82e-49bb-a911-7e95c8e6793c',
#   '0cb1a86d-66ff-4d93-97ee-86c23b2761ae',
#   '95ed2419-5593-41e3-a439-90d3a03dcbfc',
#   '973d92f1-6a92-49af-82eb-e0826921f959',
#   '6c6ef100-f52f-408b-af03-dea3fa4e86a8',
#   'c62bbb3b-8b65-4ea4-aee7-8b9a430cd0dd',
#   '0952de81-b529-4324-b357-c144f02f5697',
#   '8dbafbf8-f305-4323-9702-52a98431f734',
#   '8ad148e3-460b-46c3-9856-8c66f8e577ec',
#   'd614f3c3-bfed-4652-bf8a-99d50fad2212'],
#  'embeddings': None,
#  'documents': ['Какие достопримечательности в Шанхае?',
#   'Какие местные блюда в Шанхае?',
#   'Какие достопримечательности в Пекине?',
#   'Какие местные блюда в Пекине?',
#   'Какие достопримечательности в Ухане?',
#   'Какие местные блюда в Ухане?',
#   'Какие достопримечательности в Гонконге?',
#   'Какие местные блюда в Гонконге?',
#   'Какие достопримечательности в Макао?',
#   'Какие местные блюда в Макао?'],
#  'uris': None,
#  'data': None,
#  'metadatas': [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'},
#   {'Chapters': 'ШАНХАЙ', 'Subchapters': 'КУХНЯ'},
#   {'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'},
#   {'Chapters': 'ПЕКИН', 'Subchapters': 'КУХНЯ'},
#   {'Chapters': 'УХАНЬ', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'},
#   {'Chapters': 'УХАНЬ', 'Subchapters': 'КУХНЯ'},
#   {'Chapters': 'ГОНКОНГ', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'},
#   {'Chapters': 'ГОНКОНГ', 'Subchapters': 'КУХНЯ'},
#   {'Chapters': 'МАКАО', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'},
#   {'Chapters': 'МАКАО', 'Subchapters': 'КУХНЯ'}],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
from langchain_chroma import Chroma

# %%
vector_store_from_client = Chroma(
    client=persistent_client,
    collection_name="example_collection",
    embedding_function=sentence_transformer_ef_cl,
)

# %%
vector_store_from_client

# %%
# from langchain_core.documents import Document

# %%
# document_1 = Document(
#     page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
#     metadata={"source": "tweet"},
#     id=1,
# )

# document_2 = Document(
#     page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
#     metadata={"source": "news"},
#     id=2,
# )

# document_3 = Document(
#     page_content="Building an exciting new project with LangChain - come check it out!",
#     metadata={"source": "tweet"},
#     id=3,
# )

# document_4 = Document(
#     page_content="Robbers broke into the city bank and stole $1 million in cash.",
#     metadata={"source": "news"},
#     id=4,
# )

# document_5 = Document(
#     page_content="Wow! That was an amazing movie. I can't wait to see it again.",
#     metadata={"source": "tweet"},
#     id=5,
# )

# document_6 = Document(
#     page_content="Is the new iPhone worth the price? Read this review to find out.",
#     metadata={"source": "website"},
#     id=6,
# )

# document_7 = Document(
#     page_content="The top 10 soccer players in the world right now.",
#     metadata={"source": "website"},
#     id=7,
# )

# document_8 = Document(
#     page_content="LangGraph is the best framework for building stateful, agentic applications!",
#     metadata={"source": "tweet"},
#     id=8,
# )

# document_9 = Document(
#     page_content="The stock market is down 500 points today due to fears of a recession.",
#     metadata={"source": "news"},
#     id=9,
# )

# document_10 = Document(
#     page_content="I have a bad feeling I am going to get deleted :(",
#     metadata={"source": "tweet"},
#     id=10,
# )

# documents = [
#     document_1,
#     document_2,
#     document_3,
#     document_4,
#     document_5,
#     document_6,
#     document_7,
#     document_8,
#     document_9,
#     document_10,
# ]
# uuids = [str(uuid4()) for _ in range(len(documents))]

# vector_store.add_documents(documents=documents, ids=uuids)

# %%
results = vector_store_from_client.similarity_search(
    "Чем известен Гонконг?",
    k=2,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * Какие достопримечательности в Гонконге? [{'Chapters': 'ГОНКОНГ', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * Какие местные блюда в Гонконге? [{'Chapters': 'ГОНКОНГ', 'Subchapters': 'КУХНЯ'}]

# %% [markdown]
# ### Формирование базы эмбеддингов Chroma

# %%
persistent_client_serv = chromadb.PersistentClient(path="./serv_db_3")

# %%
collection_serv = persistent_client_serv.get_or_create_collection("serv_collection", embedding_function=sentence_transformer_ef)

# %%
documents_questions = []
metadatas_questions = []

# %%
for ind in range(data.shape[0]):
    print(f"{ind+1} {data['Chapters'][ind]}")
    requests = data['Requests'][ind].split("\n")

    for question in requests[:20]:
        req = f"{data['Chapters'][ind]} {data['Subchapters'][ind]} {question.strip()}"
        # collection_serv.add(
        #     ids=[str(uuid4())], 
        #     documents=[req],
        #     metadatas=[{"Chapters": data['Chapters'][ind], "Subchapters": data['Subchapters'][ind]}]
        # )
        documents_questions.append(req)
        metadatas_questions.append({"Chapters": data['Chapters'][ind], "Subchapters": data['Subchapters'][ind]})

    # break
# Out:
# 1 КИТАЙ
# 2 ОРГАНИЗАЦИЯ ТУРА
# 3 ВИЗЫ
# 4 СТРАХОВКА
# 5 ГОСТИНИЦЫ
# 6 КАК ДОБРАТЬСЯ ДО КИТАЯ
# 7 ПРИБЫТИЕ
# 8 ПРИБЫТИЕ
# 9 ПРИБЫТИЕ
# 10 КИТАЙ
# 11 КИТАЙ
# 12 КИТАЙ
# 13 КИТАЙ
# 14 КИТАЙ
# 15 КИТАЙ
# 16 КИТАЙ
# 17 КИТАЙ
# 18 КИТАЙ
# 19 ГОНКОНГ
# 20 ГОНКОНГ
# 21 ГОНКОНГ
# 22 ГОНКОНГ
# 23 ГОНКОНГ
# 24 ГОНКОНГ
# 25 ГОНКОНГ
# 26 ГОНКОНГ
# 27 ГОНКОНГ
# 28 ГОНКОНГ
# 29 ГУАНЧЖОУ
# 30 ГУАНЧЖОУ
# 31 ГУАНЧЖОУ
# 32 ГУАНЧЖОУ
# 33 ГУАНЧЖОУ
# 34 ГУАНЧЖОУ
# 35 ГУАНЧЖОУ
# 36 ГУАНЧЖОУ
# 37 ГУАНЧЖОУ
# 38 ГУАНЧЖОУ
# 39 ГУАНЧЖОУ
# 40 ГУЙЛИНЬ
# 41 ГУЙЛИНЬ
# 42 ГУЙЛИНЬ
# 43 ГУЙЛИНЬ
# 44 ГУЙЛИНЬ
# 45 ГУЙЛИНЬ
# 46 КУНЬМИН
# 47 КУНЬМИН
# 48 КУНЬМИН
# 49 КУНЬМИН
# 50 КУНЬМИН
# 51 КУНЬМИН
# 52 КУНЬМИН
# 53 КУНЬМИН
# 54 ЛИЦЗЯН
# 55 ЛИЦЗЯН
# 56 ЛИЦЗЯН
# 57 ЛИЦЗЯН
# 58 ЛИЦЗЯН
# 59 ЛОЯН
# 60 ЛОЯН
# 61 ЛОЯН
# 62 ЛОЯН
# 63 ЛОЯН
# 64 ЛОЯН
# 65 ЛОЯН
# 66 ЛОЯН
# 67 ЛХАСА
# 68 ЛХАСА
# 69 ЛХАСА
# 70 ЛХАСА
# 71 ЛХАСА
# 72 ЛХАСА
# 73 ЛХАСА
# 74 МАКАО
# 75 МАКАО
# 76 МАКАО
# 77 МАКАО
# 78 МАКАО
# 79 МАКАО
# 80 МАКАО
# 81 МАКАО
# 82 МАКАО
# 83 МАКАО
# 84 ПЕКИН
# 85 ПЕКИН
# 86 ПЕКИН
# 87 ПЕКИН
# 88 ПЕКИН
# 89 ПЕКИН
# 90 ПЕКИН
# 91 ПЕКИН
# 92 ПЕКИН
# 93 СИАНЬ
# 94 СИАНЬ
# 95 СИАНЬ
# 96 СИАНЬ
# 97 СИАНЬ
# 98 СИАНЬ
# 99 СИАНЬ
# 100 СИАНЬ
# 101 СУЧЖОУ
# 102 СУЧЖОУ
# 103 СУЧЖОУ
# 104 СУЧЖОУ
# 105 СУЧЖОУ
# 106 СУЧЖОУ
# 107 СУЧЖОУ
# 108 СУЧЖОУ
# 109 ТАЙВАНЬ
# 110 ТАЙВАНЬ
# 111 ТАЙВАНЬ
# 112 ТАЙВАНЬ
# 113 УРУМЧИ
# 114 УРУМЧИ
# 115 УРУМЧИ
# 116 УРУМЧИ
# 117 УРУМЧИ
# 118 УРУМЧИ
# 119 УРУМЧИ
# 120 УРУМЧИ
# 121 ХАЙНАНЬ
# 122 ХАЙНАНЬ
# 123 ХАЙНАНЬ
# 124 ХАЙНАНЬ
# 125 ХАЙНАНЬ
# 126 ХАЙНАНЬ
# 127 ХАЙНАНЬ
# 128 ХАЙНАНЬ
# 129 ХАЙНАНЬ
# 130 ХАЙНАНЬ
# 131 ХАЙНАНЬ
# 132 ХАЙНАНЬ
# 133 ХАНЧЖОУ
# 134 ХАНЧЖОУ
# 135 ХАНЧЖОУ
# 136 ХАНЧЖОУ
# 137 ХАНЧЖОУ
# 138 ХАНЧЖОУ
# 139 ЦИНДАО
# 140 ЦИНДАО
# 141 ЦИНДАО
# 142 ЦИНДАО
# 143 ЦИНДАО
# 144 ЦИНДАО
# 145 ЦИНДАО
# 146 ЦИНДАО
# 147 ЦИНДАО
# 148 ШАНХАЙ
# 149 ШАНХАЙ
# 150 ШАНХАЙ
# 151 ШАНХАЙ
# 152 ШАНХАЙ
# 153 ШАНХАЙ
# 154 ШАНХАЙ
# 155 ШАНХАЙ
# 156 ШАНХАЙ

# %%
uuids_questions = [str(uuid4()) for _ in range(len(documents_questions))]

# %%
len(documents_questions)
# Out:
# 2779

# %%
# collection_serv.get()
# Out:
# {'ids': ['36d1dbe4-08d9-4848-b627-d83dc5fa7dc9',
#   '26d6e210-835c-4b3d-a14d-0af627def152',
#   '60483ef6-305b-4273-bbf1-47083ced64d2',
#   '879d63dd-b05b-4132-85ca-4a106e97daaf',
#   'da274590-eee3-4c46-ab17-566074362d55',
#   '369f79a5-ea34-431a-9a6e-78440c8e2791',
#   'add4660f-ffcc-481b-b9f6-008b2125ee35',
#   'b0cb3484-7edc-4385-86c3-634777301bf1',
#   '696e427b-7a69-46e1-94c2-739883ba737b',
#   '4f4c0401-9f5e-4a85-8709-ce3e73c122d6',
#   '42f5d084-cdf8-4d68-b085-e2afe0a81086',
#   'ec3bc116-bac5-4542-aefa-b43953529e8d',
#   'a9d909a6-52ea-4a01-974f-afb6433385ad',
#   'bad2a37c-d703-4daf-aaf7-8d643ef41110',
#   'd56f7433-78ec-4177-840e-3f73199f8c1b',
#   'a38aeffa-ad6e-427f-9d64-cedaf86ddb10',
#   '78b059f2-713e-40bd-98ab-d1c0be2b6792',
#   '110c77dc-936f-4bd5-b3de-8ce494c3901c',
#   '870763aa-d52c-43f5-9e81-cf73f6c810eb',
#   'efff5eac-6dec-422c-9803-003bff97e745',
#   '3375ede7-6f4a-442d-8ab3-b0672af1c02a'],
#  'embeddings': None,
#  'documents': ['КИТАЙ ВВЕДЕНИЕ Какова площадь Китая по сравнению с другими странами?',
#   'КИТАЙ ВВЕДЕНИЕ Сколько островов принадлежит Китаю и какой из них самый крупный?',
#   'КИТАЙ ВВЕДЕНИЕ Какие достижения китайской науки и техники известны на мировом уровне?',
#   'КИТАЙ ВВЕДЕНИЕ Что такое Великая Китайская стена и какова ее протяженность?',
#   'КИТАЙ ВВЕДЕНИЕ Какие виды туризма наиболее популярны среди российских туристов в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Какие города обычно включаются в экскурсионные туры по Китаю?',
#   'КИТАЙ ВВЕДЕНИЕ Где можно заняться шопингом в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Что можно сделать в Макао?',
#   'КИТАЙ ВВЕДЕНИЕ Где находятся лучшие пляжи для отдыха в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Куда направляются паломники в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Каковы возможности китайской народной медицины для туристов?',
#   'КИТАЙ ВВЕДЕНИЕ Сколько турфирм действует в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Какова численность людей, задействованных в туриндустрии Китая?',
#   'КИТАЙ ВВЕДЕНИЕ Какой прогноз по количеству иностранных туристов в Китае к 2020 году?',
#   'КИТАЙ ВВЕДЕНИЕ Когда лучше всего ехать в Китай для туристов?',
#   'КИТАЙ ВВЕДЕНИЕ Как климатические зоны Китая влияют на выбор времени для визита?',
#   'КИТАЙ ВВЕДЕНИЕ Почему весна и осень считаются туристскими сезонами в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Почему остров Хайнань является круглогодичным курортом?',
#   'КИТАЙ ВВЕДЕНИЕ Какие древние столицы можно посетить в Китае?',
#   'КИТАЙ ВВЕДЕНИЕ Каковы основные достижения китайцев в области изобретений?',
#   'КИТАЙ ВВЕДЕНИЕ Что такое экскурсионный тур и что он включает в себя в Китае?'],
#  'uris': None,
#  'data': None,
#  'metadatas': [{'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'},
#   {'Chapters': 'КИТАЙ', 'Subchapters': 'ВВЕДЕНИЕ'}],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
import time

# %%
start_time = time.time()

collection_serv.add(
    ids=uuids_questions, 
    documents=documents_questions,
    metadatas=metadatas_questions
)

response_time = time.time() - start_time
print(f"Время заполнения: {response_time:.4f} секунды")
# Out:
# Время заполнения: 745.4415

# %%
start_time = time.time()

vector_store_serv_from_client = Chroma(
    client=persistent_client_serv,
    collection_name="serv_collection",
    embedding_function=sentence_transformer_ef_cl,
)

response_time = time.time() - start_time
print(f"Время построения клиента: {response_time:.4f} секунды")
# Out:
# Время построения с эмбеддингами: 0.0050 секунды

# %%
results = vector_store_serv_from_client.similarity_search(
    "Где находится Запретный город?",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова площадь Запретного города? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова длина крепостной стены Запретного города? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова стоимость билета в Запретный город? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]

# %%
results = vector_store_serv_from_client.similarity_search(
    "Какие достопримечательности в Шанхае?",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * ШАНХАЙ ПОКУПКИ Каковы главные достопримечательности шопинга в Шанхае? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ПОКУПКИ'}]
# * ШАНХАЙ МУЗЕИ Где находится Музей истории Шанхая? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'МУЗЕИ'}]
# * ШАНХАЙ ПОКУПКИ Какие торговые комплексы стоит посетить в Шанхае? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ПОКУПКИ'}]

# %% [markdown]
# ### Формирование рабочего варианта базы Chroma

# %%
persistent_client_serv_res = chromadb.PersistentClient(path="./serv_db_res_crop")

# %%
collection_serv_res = persistent_client_serv_res.get_or_create_collection("serv_collection", embedding_function=sentence_transformer_ef)

# %%
documents_questions = []
metadatas_questions = []

# %%
for ind in range(data.shape[0]):
    requests = data['Requests'][ind].split("\n")
    print(f"{ind+1} {data['Chapters'][ind]} вопросов: {len(requests)}")

    for question in requests[:50]:
        req = f"{data['Chapters'][ind]} {data['Subchapters'][ind]} {question.strip()}"
        documents_questions.append(req)
        metadatas_questions.append({"Chapters": data['Chapters'][ind], "Subchapters": data['Subchapters'][ind]})
# Out:
# 1 КИТАЙ вопросов: 21
# 2 ОРГАНИЗАЦИЯ ТУРА вопросов: 969
# 3 ВИЗЫ вопросов: 835
# 4 СТРАХОВКА вопросов: 15
# 5 ГОСТИНИЦЫ вопросов: 942
# 6 КАК ДОБРАТЬСЯ ДО КИТАЯ вопросов: 778
# 7 ПРИБЫТИЕ вопросов: 10
# 8 ПРИБЫТИЕ вопросов: 20
# 9 ПРИБЫТИЕ вопросов: 20
# 10 КИТАЙ вопросов: 20
# 11 КИТАЙ вопросов: 880
# 12 КИТАЙ вопросов: 21
# 13 КИТАЙ вопросов: 22
# 14 КИТАЙ вопросов: 16
# 15 КИТАЙ вопросов: 21
# 16 КИТАЙ вопросов: 21
# 17 КИТАЙ вопросов: 1021
# 18 КИТАЙ вопросов: 21
# 19 ГОНКОНГ вопросов: 904
# 20 ГОНКОНГ вопросов: 21
# 21 ГОНКОНГ вопросов: 848
# 22 ГОНКОНГ вопросов: 30
# 23 ГОНКОНГ вопросов: 835
# 24 ГОНКОНГ вопросов: 21
# 25 ГОНКОНГ вопросов: 1114
# 26 ГОНКОНГ вопросов: 13
# 27 ГОНКОНГ вопросов: 20
# 28 ГОНКОНГ вопросов: 11
# 29 ГУАНЧЖОУ вопросов: 21
# 30 ГУАНЧЖОУ вопросов: 10
# 31 ГУАНЧЖОУ вопросов: 21
# 32 ГУАНЧЖОУ вопросов: 40
# 33 ГУАНЧЖОУ вопросов: 17
# 34 ГУАНЧЖОУ вопросов: 16
# 35 ГУАНЧЖОУ вопросов: 21
# 36 ГУАНЧЖОУ вопросов: 1088
# 37 ГУАНЧЖОУ вопросов: 20
# 38 ГУАНЧЖОУ вопросов: 14
# 39 ГУАНЧЖОУ вопросов: 20
# 40 ГУЙЛИНЬ вопросов: 21
# 41 ГУЙЛИНЬ вопросов: 21
# 42 ГУЙЛИНЬ вопросов: 870
# 43 ГУЙЛИНЬ вопросов: 20
# 44 ГУЙЛИНЬ вопросов: 21
# 45 ГУЙЛИНЬ вопросов: 15
# 46 КУНЬМИН вопросов: 21
# 47 КУНЬМИН вопросов: 20
# 48 КУНЬМИН вопросов: 21
# 49 КУНЬМИН вопросов: 25
# 50 КУНЬМИН вопросов: 21
# 51 КУНЬМИН вопросов: 16
# 52 КУНЬМИН вопросов: 20
# 53 КУНЬМИН вопросов: 13
# 54 ЛИЦЗЯН вопросов: 1229
# 55 ЛИЦЗЯН вопросов: 21
# 56 ЛИЦЗЯН вопросов: 20
# 57 ЛИЦЗЯН вопросов: 17
# 58 ЛИЦЗЯН вопросов: 10
# 59 ЛОЯН вопросов: 16
# 60 ЛОЯН вопросов: 21
# 61 ЛОЯН вопросов: 21
# 62 ЛОЯН вопросов: 25
# 63 ЛОЯН вопросов: 15
# 64 ЛОЯН вопросов: 10
# 141 ЦИНДАО вопросов: 21
# 142 ЦИНДАО вопросов: 962
# 143 ЦИНДАО вопросов: 16
# 144 ЦИНДАО вопросов: 20
# 145 ЦИНДАО вопросов: 21
# 146 ЦИНДАО вопросов: 21
# 147 ЦИНДАО вопросов: 21
# 148 ШАНХАЙ вопросов: 21
# 149 ШАНХАЙ вопросов: 27
# 150 ШАНХАЙ вопросов: 701
# 151 ШАНХАЙ вопросов: 995
# 152 ШАНХАЙ вопросов: 721
# 153 ШАНХАЙ вопросов: 21
# 154 ШАНХАЙ вопросов: 15
# 155 ШАНХАЙ вопросов: 21
# 156 ШАНХАЙ вопросов: 16

# %%
len(documents_questions)
# Out:
# 3535

# %%
uuids_questions = [str(uuid4()) for _ in range(len(documents_questions))]

# %%
start_time = time.time()

collection_serv_res.add(
    ids=uuids_questions, 
    documents=documents_questions,
    metadatas=metadatas_questions
)

response_time = time.time() - start_time
print(f"Время заполнения: {response_time:.3f} секунды")
# Out:
# Время заполнения: 991.082 секунды

# %%
start_time = time.time()

vector_store_serv_res_from_client = Chroma(
    client=persistent_client_serv_res,
    collection_name="serv_collection",
    embedding_function=sentence_transformer_ef_cl,
)

response_time = time.time() - start_time
print(f"Время построения клиента: {response_time:.3f} секунды")
# Out:
# Время построения клиента: 0.005 секунды

# %%
start_time = time.time()

results = vector_store_serv_res_from_client.similarity_search(
    "Какие достопримечательности в Шанхае?",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")

response_time = time.time() - start_time
print(f"Время обработки запроса: {response_time:.7f} секунды")
# Out:
# * ШАНХАЙ ПОКУПКИ Каковы главные достопримечательности шопинга в Шанхае? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ПОКУПКИ'}]
# * ШАНХАЙ ДОСТОПРИМЕЧАТЕЛЬНОСТИ Что можно увидеть в музее истории Шанхая? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * ШАНХАЙ МУЗЕИ Где находится Музей истории Шанхая? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'МУЗЕИ'}]
# Время обработки запроса: 0.3476250 секунды

# %%
start_time = time.time()

results = vector_store_serv_res_from_client.similarity_search(
    "Где находится Запретный город?",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")

response_time = time.time() - start_time
print(f"Время обработки запроса: {response_time:.7f} секунды")
# Out:
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова площадь Запретного города? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова длина крепостной стены Запретного города? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# * ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова стоимость билета в Запретный город? [{'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}]
# Время обработки запроса: 0.2335246 секунды

# %%
start_time = time.time()

results = vector_store_serv_res_from_client.similarity_search(
    "Расскажи про историю Китая",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")

response_time = time.time() - start_time
print(f"Время обработки запроса: {response_time:.7f} секунды")
# Out:
# * КИТАЙ НАСЕЛЕНИЕ Какова история ханьцев? [{'Chapters': 'КИТАЙ', 'Subchapters': 'НАСЕЛЕНИЕ'}]
# * КИТАЙ НЕМНОГО ИСТОРИИ Какова история доисторического периода Китая? [{'Chapters': 'КИТАЙ', 'Subchapters': 'НЕМНОГО ИСТОРИИ'}]
# * КИТАЙ ОБЩАЯ ИНФОРМАЦИЯ Какое население у Китая? [{'Chapters': 'КИТАЙ', 'Subchapters': 'ОБЩАЯ ИНФОРМАЦИЯ'}]
# Время обработки запроса: 0.2179425 секунды

# %%
start_time = time.time()

results = vector_store_serv_res_from_client.similarity_search(
    "Какой транспорт в Шанхае?",
    k=3,
    # filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")

response_time = time.time() - start_time
print(f"Время обработки запроса: {response_time:.7f} секунды")
# Out:
# * ШАНХАЙ ТРАНСПОРТ Сколько маршрутов общественного транспорта в Шанхае? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ТРАНСПОРТ'}]
# * ШАНХАЙ РАЗВЛЕЧЕНИЯ Какой транспорт удобен для посещения развлекательных заведений в Шанхае? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'РАЗВЛЕЧЕНИЯ'}]
# * ШАНХАЙ ТРАНСПОРТ Какой вид транспорта в Шанхае не касается поверхности рельса во время движения? [{'Chapters': 'ШАНХАЙ', 'Subchapters': 'ТРАНСПОРТ'}]
# Время обработки запроса: 0.2594244 секунды

# %%
res.metadata, res.metadata['Chapters'], res.metadata['Subchapters']
# Out:
# ({'Chapters': 'ШАНХАЙ', 'Subchapters': 'ТРАНСПОРТ'}, 'ШАНХАЙ', 'ТРАНСПОРТ')

# %%
data.loc[(data['Chapters'] == res.metadata['Chapters']) & (data['Subchapters'] == res.metadata['Subchapters'])].index[0]
# Out:
# 149

# %%
data.loc[(data['Chapters'] == res.metadata['Chapters']) & (data['Subchapters'] == res.metadata['Subchapters']), 'Clean_Text'].values[0]
# Out:
# 'Шанхай единственный в Китае город, который имеет 2 аэропорта. Аэропорт «Хунцяо» находится в западной части города в 13 км от центральной площади Жэньминь. Международный аэропорт «Пудун» расположен в приморской зоне Пудунского нового района. Расстояние до города составляет 30 км, до «Хунцяо» 40 км. Специальный автобусный маршрут №1 связывает аэропорт «Пудун» с аэропортом «Хунцяо»; №2 с Шанхайским выставочным центром; №3 с ул. Цзуньилу (отель «Янцзы»); №4 с ул. Дунцзянваньлу (парк им. Лу Синя); №5 с Шанхайским вокзалом; №6 с Западным вокзалом. Чтобы увидеть воплощенные в реальность новейшие технические разработки, прокатитесь на скоростном поезде на магнитной подушке. Во время движения поезд «Maglev», напоминающий ракету, движется почти бесшумно и очень плавно. Не веришь глазам, когда на табло высвечивается его скорость 431 км/час! На дорогу уходит всего 7,5 мин. Такой состав, в отличие от традиционных поездов, во время движения не касается поверхности рельса. Строительство линии длиной 33 км обошлось в 10 млрд юаней. Она начинается у станции метро «Лунъянлу» (линия 2) и заканчивается в аэропорту «Пудун». В Шанхае имеется более 1000 маршрутов общественного транспорта. Стоимость проезда на обычном автобусе в черте города составляет 1-4 юаня; на автобусе с кондиционером 2-3 юаня. Отправная цена на такси равна 10 юаням. В период с 23.00 до 5.00 стоимость увеличивается на 30%. Все автомобили оснащены счетчиками. Шанхайский метрополитен насчитывает 12 линий и 267 станций. На метро можно легко добраться до большинства достопримечательностей и крупных торговых центров, однако стоит избегать часов пик с 7.00 до 9.30 и с 16.30 до 19.30. Имеются специальные туристические автобусы, маршруты которых проходят через основные достопримечательности города и его окрестностей. Имеется свыше 60 туристических маршрутов, которые обслуживают около 400 автобусов. В автобусах работают гиды, которые знакомят пассажиров с достопримечательностями. Льготные билеты, включающие входные билеты в музеи, продают в Центрах туристических поездок. Они имеются у автостоянки №4 Шанхайского стадиона и возле футбольного поля «Хункоу».'

# %% [markdown]
# ## Функция потоковой генерации

# %%
import asyncio

# %%
user_request = "Расскажи подробно про Запретный город"

# %%
messages = []

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, trim_messages

# %%
llm_max = GigaChat(
    credentials=os.environ.get("GIGACHAT_API_KEY"),
    scope="GIGACHAT_API_PERS",
    model="GigaChat-Max",
    # Отключает проверку наличия сертификатов НУЦ Минцифры
    verify_ssl_certs=False,
    streaming=True, #False,
)

# %%
trimmer = trim_messages(
    max_tokens=31000,
    strategy="last",
    token_counter=llm_max,
    include_system=True,
    allow_partial=False,
    start_on="human",
)

# %%
sys_mess = SystemMessage(content="Ты профессиональный путеводетель по Китаю. Ты подробно отвечаешь на запросы пользователя используя контекст. Придерживайся фактов!")
messages.append(sys_mess)

# %%
results = vector_store_serv_res_from_client.similarity_search(
    user_request,
    k=2,
)

prompt = f"{user_request}\nКонтекст:\n"
if (results[0].metadata['Chapters'] == results[1].metadata['Chapters']) and (results[0].metadata['Subchapters'] == results[1].metadata['Subchapters']):
    prompt += data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"
else:
    prompt += "* " + data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n* " + \
        data.loc[(data['Chapters'] == results[1].metadata['Chapters']) & (data['Subchapters'] == results[1].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"

print(data.loc[(data['Chapters'] == res.metadata['Chapters']) & (data['Subchapters'] == res.metadata['Subchapters'])].index[0])

messages.append(HumanMessage(content=prompt))
# Out:
# 149

# %%
results
# Out:
# [Document(metadata={'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}, page_content='ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Какова стоимость билета в Запретный город?'),
#  Document(metadata={'Chapters': 'ПЕКИН', 'Subchapters': 'ДОСТОПРИМЕЧАТЕЛЬНОСТИ'}, page_content='ПЕКИН ДОСТОПРИМЕЧАТЕЛЬНОСТИ Как была устроена система отопления в Запретном городе?')]

# %%
print(messages[-1].content[:150])
# Out:
# Расскажи подробно про Запретный город
# Контекст:
# Площадь Тяньаньмэнь. Авт. 1, 2, 4, 5, 10, 20, 22, 52, 54, 57, 120, 802, 9, 17, 44, 48, 53, 59, 66, 110

# %%
for chunk in llm_max.stream(messages):
    print(chunk) # (chunk.choices[0].delta.content, end="", flush=True)
# Out:
# content='Запретный город — это крупнейший в мире дворцовый комплекс, расположенный в центре Пекина, столице Китая.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' Он был построен в начале XV века и служил главной резиденцией китайских императоров на протяжении почти 500 лет, начиная с династии Мин и заканчивая династией Цин.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' \n\nНазвание "Запретный город" происходит от того факта, что простым людям запрещалось входить внутрь комплекса без специального разрешения.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' Город окружён крепостной стеной высотой 10 метров и длиной 3500 метров, а также глубоким рвом шириной 52 метра, наполненным водой.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' Внутри Запретного города находятся более 9000 различных помещений, включая жилые здания, храмы, сады и другие постройки.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content='\n\nДворец Гугун, известный также как Запретный город, занимает площадь 720 тысяч квадратных метров и включает в себя множество архитектурных шедевров.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' Наиболее известные из них включают Зал Высшей Гармонии (Тайхэдянь), Зал Центральной Гармонии (Чжунхэдянь) и Зал Сохранённой Гармонии (Бао хэдянь).' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content=' Эти три зала составляют сердце политической власти империи и используются для проведения важных церемоний и приёмов.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content='\n\nКроме того, в Запретном городе есть множество садов, прудов и павильонов, которые создают гармоничное сочетание природы и архитектуры.' additional_kwargs={} response_metadata={} id='run-1eb58482-2f9f-41e7-b5ac-95c5ed965e88'
# content='
ional_kwargs={}, response_metadata={'finish_reason': 'stop'}, id='run-78a36f2d-c5a1-4d82-a601-d5c864e1d18b-0')

# %%
ansver = ""
for chunk in llm_max.stream(messages):
    ansver += chunk.content
    print(chunk.content, end="", flush=True)

messages.append(AIMessage(ansver))
# Out:
# Запретный город — это грандиозный дворцовый комплекс, расположенный в центре Пекина, Китай. Он был построен в начале XV века и служил резиденцией для 24 императоров династий Мин и Цин на протяжении почти 500 лет. Запретный город является самым большим историческим памятником Китая и самым крупным в мире музеем под открытым небом.
#
# ### Основные характеристики
#
# - **Название**: Запретный город, также известен как Гугун («Дворец бывших правителей»).
# - **Расположение**: Центр Пекина, рядом с площадью Тяньаньмэнь.
# - **Строительство**: Началось в 1406 году и завершилось в 1420 году.
# - **Площадь**: Около 720 тысяч квадратных метров.
# - **Количество сооружений**: Более 980 зданий и около 8700 комнат.
# - **Значение**: Был политическим центром Китая и символом императорской власти.
#
# ### Архитектура и планировка
#
# Запретный город состоит из двух основных частей: Внешнего двора и Внутреннего двора. Внешний двор использовался для официальных церемоний и приемов, тогда как Внутренний двор был жилым пространством императорской семьи и высших чиновников.
#
# - **Внешний двор** включает в себя три главные здания: Зал Верховной гармонии (Тайхэдянь), Зал Полной гармонии (Чжунхэдянь) и Зал Сохранения гармонии (Бао-хэдянь). Эти здания использовались для проведения важных государственных мероприятий.
#
# - **Внутренний двор** включал жилые помещения императорской семьи, такие как Палаты небесной чистоты (Цяньцингун), Палата земного спокойствия (Куньнингун) и другие. Также здесь располагались сады, храмы и административные здания.
#
# ### История
#
# Запретный город был закрыт для простых граждан на протяжении веков, отсюда и его название "Запретный". После падения последней императорской династии Цин в 1912 году, Запретный город стал музеем и открыт для публики. Сегодня он является популярным туристическим объектом и важным культурным наследием Китая.
#
# ### Посещение
#
# Для посетителей доступны различные маршруты осмотра, включая основные здания и экспозиции музея. Входные билеты можно приобрести на месте или заранее онлайн. Рекомендуется планировать посещение заранее, так как количество билетов ограничено.
#
# Запретный город — это уникальное место, где можно погрузиться в историю и культуру Китая, а также насладиться величественной архитектурой и атмосферой прошлого.

# %%
len(messages)
# Out:
# 3

# %%
# trimmer.invoke(messages)

# %%
len(messages)
# Out:
# 3

# %% [markdown]
# ### GigaChat-light

# %%
llm_light = GigaChat(
    credentials=os.environ.get("GIGACHAT_API_KEY"),
    scope="GIGACHAT_API_PERS",
    model="GigaChat",
    # Отключает проверку наличия сертификатов НУЦ Минцифры
    verify_ssl_certs=False,
    streaming=True, #False,
)

# %%
messages = []

# %%
sys_mess = SystemMessage(content="Ты профессиональный путеводетель по Китаю. Ты подробно отвечаешь на запросы пользователя используя контекст. Придерживайся фактов!")
messages.append(sys_mess)

# %%
results = vector_store_serv_res_from_client.similarity_search(
    user_request,
    k=2,
)

prompt = f"{user_request}\nКонтекст:\n"
if (results[0].metadata['Chapters'] == results[1].metadata['Chapters']) and (results[0].metadata['Subchapters'] == results[1].metadata['Subchapters']):
    prompt += data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"
else:
    prompt += "* " + data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n* " + \
        data.loc[(data['Chapters'] == results[1].metadata['Chapters']) & (data['Subchapters'] == results[1].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"

print(data.loc[(data['Chapters'] == res.metadata['Chapters']) & (data['Subchapters'] == res.metadata['Subchapters'])].index[0])

messages.append(HumanMessage(content=prompt))
# Out:
# 149

# %%
# ansver = ""
# for chunk in llm_max.stream(messages):
#     ansver += chunk.content
#     print(chunk.content, end="", flush=True)

# messages.append(AIMessage(ansver))
# Out:
# Запретный город — это дворцовый комплекс в центре Пекина, который был резиденцией китайских императоров с 1420 года до начала XX века. Он также известен как "Гугун" или "Императорский дворец".
#
# Комплекс имеет прямоугольную форму и занимает площадь около 720 тысяч квадратных метров. Он окружён крепостной стеной высотой 10 метров и рвом шириной 52 метра. Внутри комплекса находятся 980 зданий, которые включают различные дворцы, храмы, сады и другие постройки. Всего в Запретном городе насчитывается 9999 комнат, что символизирует власть императора, приближенную к власти небесного императора, у которого было 10 000 комнат.
#
# История Запретного города начинается в 1406 году, когда третий император династии Мин, Юнлэ, начал строительство нового дворца в Пекине. Строительство продолжалось 14 лет и завершилось в 1420 году. С тех пор Запретный город стал главной резиденцией императоров Китая вплоть до падения последней императорской династии Цин в 1912 году.
#
# В 1987 году Запретный город был внесён в Список объектов всемирного наследия ЮНЕСКО. Сегодня он является одним из самых популярных туристических объектов в Китае, привлекающим миллионы посетителей каждый год.

# %%
ansver = ""
for chunk in llm_light.stream(messages):
    ansver += chunk.content
    print(chunk.content, end="", flush=True)

messages.append(AIMessage(ansver))
# Out:
# Запретный город (Гугун) — это один из наиболее значимых исторических объектов Китая, который также считается самым большим дворцовым комплексом в мире. Строительство этого комплекса началось в 1406 году и продолжалось до 1420 года. Дворцовый комплекс занимает площадь в 72 гектара и включает в себя около 9999 отдельных помещений. Запретный город был официальной резиденцией императоров династий Мин и Цин вплоть до 1912 года, когда последний император Пу И покинул дворец после Синьхайской революции.
#
# Комплекс окружён высокой крепостной стеной и глубоким рвом, которые служат дополнительной защитой. Главная архитектурная идея Запретного города — сочетание ландшафтного дизайна и сооружений, создающих единый ансамбль. Вся территория делится на внутренний и внешний дворы, каждый из которых имеет свои функции и особенности. Внутренний двор использовался исключительно для официальных мероприятий и повседневной жизни императора, тогда как внешний двор был доступен для придворных и знатных гостей.
#
# Запретный город является примером классической китайской архитектуры, основанной на принципах фэн-шуй и символизме чисел. Например, количество помещений в комплексе соответствует "идеальному" числу, которым должно обладать земное божество — 9999. Эта цифра символизирует бесконечность и власть императора.
#
# Сегодня Запретный город превращён в музей, известный как Национальный дворец-музей. В нём представлены экспонаты, относящиеся к различным эпохам китайской истории, включая произведения искусства, мебель, керамику, текстиль и другие предметы быта. Комплекс включён в Список всемирного наследия ЮНЕСКО и является одной из самых популярных туристических достопримечательностей Китая.

# %%
# trimmer.invoke(messages)

# %% [markdown]
# ## Компоновка сервера

# %%
import os
import getpass

# %%
import asyncio
import uvicorn
import logging

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from fastapi.responses import StreamingResponse

# %%
from langchain_gigachat.chat_models import GigaChat
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, trim_messages

# %%
from langchain_chroma import Chroma
import chromadb

# %%
# Инициализация логирования
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# Запрашиваем токен
def set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

set_env("GIGACHAT_API_KEY")

# %%
# Загружаем модель
model = GigaChat(
    credentials=os.environ.get("GIGACHAT_API_KEY"),
    scope="GIGACHAT_API_PERS",
    model="GigaChat",
    # Отключает проверку наличия сертификатов НУЦ Минцифры
    verify_ssl_certs=False,
    streaming=True, #False,
)

# %%
# Загружаем датасет
data = pd.read_csv("2024_12_14 China full 02.csv")

# %%
# Грузим эмбеддинги и базу Chroma
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="intfloat/multilingual-e5-large")
sentence_transformer_ef_cl = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")

persistent_client_serv = chromadb.PersistentClient(path="./serv_db_res_crop")
collection_serv = persistent_client_serv.get_or_create_collection("serv_collection", embedding_function=sentence_transformer_ef)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: intfloat/multilingual-e5-large

# %%
# Создаеём клиента векторной базы
vector_store_from_client = Chroma(
    client=persistent_client_serv,
    collection_name="serv_collection",
    embedding_function=sentence_transformer_ef_cl,
)

# %%
# Функция добавления контекста к пользовательскому запросу
def get_human_message(answer: str):
    results = vector_store_from_client.similarity_search(
        answer,
        k=2,
    )
    
    prompt = f"{answer}\nКонтекст:\n"
    if (results[0].metadata['Chapters'] == results[1].metadata['Chapters']) and (results[0].metadata['Subchapters'] == results[1].metadata['Subchapters']):
        prompt += data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"
    else:
        prompt += "* " + data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n* " + \
            data.loc[(data['Chapters'] == results[1].metadata['Chapters']) & (data['Subchapters'] == results[1].metadata['Subchapters']), 'Clean_Text'].values[0] + "\n"
    
    ind = int(data.loc[(data['Chapters'] == results[0].metadata['Chapters']) & (data['Subchapters'] == results[0].metadata['Subchapters'])].index[0])

    return (HumanMessage(content=prompt), ind)

# %%
# Создаём и инициализируем очередь сообщений
messages = []

messages.append(SystemMessage(content="Ты профессиональный путеводетель по Китаю. Ты подробно отвечаешь на запросы пользователя используя контекст. Придерживайся фактов!"))

# %%
# Функция генерации ответов
async def generate(messages, index: int):
    logger.info(f"Зпрос пользователя. Index: {index} Запрос: {messages[-1]}")

    index_pack = {
        "index": index
    }
    yield json.dumps(index_pack)
    await asyncio.sleep(0.1)

    ansver = ""
    for chunk in model.stream(messages):
        ansver += chunk.content
        print(chunk.content, end="", flush=True)
        response_part = {
            "content": f"{chunk.content}"
        }

        yield json.dumps(response_part)    # json.dumps(delta)
        await asyncio.sleep(0.025)
    
    messages.append(AIMessage(ansver))
    logger.info(f"Ответ путеводителя. Index: {index} Запрос: {messages[-1]}")

# %%
# Инициализация FastAPI
app = FastAPI()

# %%
class ChatMessage(BaseModel):
    content: str

# %%
@app.post("/chat")
async def chat_endpoint(chat_message: ChatMessage):
    
    message, index = get_human_message(chat_message.content)
    messages.append(message)
    
    trim_messages(
        messages,
        max_tokens=32000,
        strategy="last",
        token_counter=model,
        include_system=True,
        allow_partial=False,
        start_on="human",
    )

    return StreamingResponse(generate(messages, index), media_type="text/plain")  # return answer
